# %%
import matplotlib.pyplot as plt
import numpy as np


x,x1,x2,x3,x4=np.loadtxt("D3.txt",unpack=True)

sig=x
#x=np.loadtxt("RunUp.txt",unpack=True)

dt = 3600/len(sig)

t = np.arange(0,3600, 3600/len(sig))



NFFT = 256       # the length of the windowing segments  1024   256
Fs = int(1.0/dt)  # the sampling frequency

# Pxx is the segments x freqs array of instantaneous power, freqs is
# the frequency vector, bins are the centers of the time bins in which
# the power is computed, and im is the matplotlib.image.AxesImage
# instance

#ax1 = plt.subplot(211)
#plt.plot(t, x)
#plt.subplot(212, sharex=ax1)
Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=200)
#plt.ylim(0,100)
plt.show()
